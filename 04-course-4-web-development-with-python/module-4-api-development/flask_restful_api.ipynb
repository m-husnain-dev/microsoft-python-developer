# %%
# !pip install nest_asyncio flask flask_restful
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.13/dist-packages (1.6.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.13/dist-packages (3.1.3)
# Collecting flask_restful
#   Downloading Flask_RESTful-0.3.10-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.13/dist-packages (from flask) (8.4.2)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.13/dist-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from flask) (3.1.8)
# Collecting aniso8601>=0.82 (from flask_restful)
#   Downloading aniso8601-10.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: six>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from flask_restful) (1.17.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.13/dist-packages (from flask_restful) (2025.2)
# Downloading Flask_RESTful-0.3.10-py2.py3-none-any.whl (26 kB)
# Downloading aniso8601-10.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: aniso8601, flask_restful
# Successfully installed aniso8601-10.0.1 flask_restful-0.3.10

# %%
import nest_asyncio
from flask import Flask, request
from flask_restful import Api, Resource
from threading import Thread

# %%
books = [
    {"isbn": "1234567890", "title": "The Great Gatsby", "author": "F. Scott Fitzgerald", "price": 10.99},
    {"isbn": "0987654321", "title": "1984", "author": "George Orwell", "price": 8.99}
]

# %%
app = Flask(__name__)
api = Api(app)

# %%
    def get(self, isbn=None):
        if isbn:
            for book in books:
                if book['isbn'] == isbn:
                    return book, 200
            return {"message": "Book not found"}, 404
        return books, 200

# %%
    def post(self):
        new_book = request.json
        books.append(new_book)
        return new_book, 201

# %%
    def put(self, isbn):
        for book in books:
            if book['isbn'] == isbn:
                book.update(request.json)
                return book, 200
        return {"message": "Book not found"}, 404

# %%
    def delete(self, isbn):
        global books
        books = [book for book in books if book['isbn'] != isbn]
        return {"message": "Book deleted"}, 200

# %%
nest_asyncio.apply()
def run_app():
    app.run(port=5000, debug=False)

thread = Thread(target=run_app)
thread.start()

print("API is running! Test it at http://127.0.0.1:5000/books")
# Out:
# API is running! Test it at http://127.0.0.1:5000/books

# %%
{
  "isbn": "1122334455",
  "title": "Brave New World",
  "author": "Aldous Huxley",
  "price": 12.99
}
# Out:
# {'isbn': '1122334455',
#  'title': 'Brave New World',
#  'author': 'Aldous Huxley',
#  'price': 12.99}

# %%
{
  "title": "Brave New World - Updated Edition",
  "author": "Aldous Huxley",
  "price": 14.99
}
# Out:
# {'title': 'Brave New World - Updated Edition',
#  'author': 'Aldous Huxley',
#  'price': 14.99}
