# %%
# !pip install flask pytest pytest-asyncio

# %%
# %%writefile app.py
from flask import Flask, jsonify, request

app = Flask(__name__)

@app.route('/api/data', methods=['GET'])
def get_data():
    return jsonify({"status": "success", "data": "Hello from Colab!"}), 200

@app.route('/api/data', methods=['POST'])
def add_data():
    payload = request.get_json()
    if not payload or 'name' not in payload:
        return jsonify({"error": "Name field required"}), 400
    return jsonify({"message": f"Data received for {payload['name']}"}), 201
# Out:
# Writing app.py

# %%
# %%writefile test_app.py
import pytest
from app import app

@pytest.fixture
def client():
    app.config['TESTING'] = True
    with app.test_client() as client:
        yield client

def test_get_data(client):
    response = client.get('/api/data')
    assert response.status_code == 200
    assert response.json['status'] == 'success'

def test_add_data_success(client):
    response = client.post('/api/data', json={'name': 'Colab User'})
    assert response.status_code == 201
    assert response.json['message'] == 'Data received for Colab User'
# Out:
# Writing test_app.py

# %%
# !pytest test_app.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: asyncio-1.4.0, langsmith-0.11.0, anyio-4.14.2, typeguard-4.6.0
# asyncio: mode=Mode.STRICT, debug=False, asyncio_default_fixture_loop_scope=None, asyncio_default_test_loop_scope=function
# collected 2 items
#
# test_app.py ..                                                           [100%]
#
# ============================== 2 passed in 0.33s ===============================
